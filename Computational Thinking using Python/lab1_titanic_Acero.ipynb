# %% [markdown]
# <a href="https://colab.research.google.com/github/vpcacero/Numerical-and-Symbolic-Computation/blob/main/Laboratory_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **QUESTION 1**
#
# 1. Upload the dataset to session storage.
# 2. Load the CSV file using pandas.
# 3. Inspect its structure

# %%
import pandas as pd
# Load the dataset
df = pd.read_csv("titanic.csv")
# Display the first few rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **QUESTION 2**
#
# 1. Check for the missing values.
# 2. Get the total number of missing values per column.
# 3. Display the result.
#
# Age, cabin and embarked are the columns that contains the missing values. Cabin is missing 687 values which is more than half so it's best to remove it as it is unreliable. Embark has only missing 2 values so it can be filled.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **QUESTION 3**
#
# 1. Count the total number of passengers.
# 2. Count the total number of passengers that survived.
# 3. Divide the total number of passengers to the total number of passengers that survived.
# 4. Multiply the result to 100 and display.
#
# The incident has a low survival rate with 38%.

# %%
df["Survived"].mean()
# Out:
# 0.3838383838383838

# %% [markdown]
# **QUESTION 4**
#
# 1. Filter survivors and non-survivors from the dataset.
# 2. Calculate the average age for each group.
# 3. Display the result.
#
# Based from the results, the average age of survivors is younger than those who don't. Therefore, it can be concluded that age has an impact to survival.

# %%
import matplotlib.pyplot as plt
# Plot age distribution of survivors vs. non-survivors
plt.hist(df[df["Survived"] == 1]["Age"].dropna(), bins=20, alpha=0.5, label="Survived")
plt.hist(df[df["Survived"] == 0]["Age"].dropna(), bins=20, alpha=0.5, label="Did Not Survive")
plt.legend()
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()
